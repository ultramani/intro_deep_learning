# %% [markdown]
# <a href="https://colab.research.google.com/github/ultramani/intro_deep_learning/blob/main/class/Fundamentals/Prevent_Overfitting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# It is highly recommended to use a powerful **GPU**, you can use it for free uploading this notebook to [Google Colab](https://colab.research.google.com/notebooks/intro.ipynb).
# <table align="center">
#  <td align="center"><a target="_blank" href="https://colab.research.google.com/github/ezponda/intro_deep_learning/blob/main/class/Fundamentals/Prevent_Overfitting.ipynb">
#         <img src="https://colab.research.google.com/img/colab_favicon_256px.png"  width="50" height="50" style="padding-bottom:5px;" />Run in Google Colab</a></td>
#   <td align="center"><a target="_blank" href="https://github.com/ezponda/intro_deep_learning/blob/main/class/Fundamentals/Prevent_Overfitting.ipynb">
#         <img src="https://github.githubassets.com/images/modules/logos_page/GitHub-Mark.png"  width="50" height="50" style="padding-bottom:5px;" />View Source on GitHub</a></td>
# </table>

# %% [markdown]
# # Prevent Overfitting: Regularization

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow import keras
from tensorflow.keras import layers
tf.random.set_seed(0)

def plot_history(history: tf.keras.callbacks.History) -> None:
    """Plot training and validation loss/accuracy curves.

    Args:
        history: History object returned by model.fit()
    """
    hist = pd.DataFrame(history.history)
    hist['epoch'] = history.epoch

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

    # Loss plot
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Loss')
    ax1.plot(hist['epoch'], hist['loss'], label='Train')
    ax1.plot(hist['epoch'], hist['val_loss'], label='Validation')
    ax1.legend()
    ax1.grid(True)

    # Accuracy plot
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Accuracy')
    ax2.plot(hist['epoch'], hist['accuracy'], label='Train')
    ax2.plot(hist['epoch'], hist['val_accuracy'], label='Validation')
    ax2.legend()
    ax2.grid(True)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# We will use the [MNIST dataset](https://en.wikipedia.org/wiki/MNIST_database), consisting of a collection of 28x28 pixel images corresponding in digits from 0 to 9 manuscripts. The purpose of this data set is to train models that recognize handwritten numbers.
#
# We will train, therefore, an [OCR (Optical Character Recognition)](https://en.wikipedia.org/wiki/Optical_character_recognition) model for multiclass classification (numbers from 0 to 9).

# %%
mnist = tf.keras.datasets.mnist
(x_train, y_train),(x_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
x_train[0].shape
# Out:
# (28, 28)

# %% [markdown]
# As they are 8-bit images, the colors (in this case only one channel, the gray channel) of each pixel are encoded with a value between 0 and 255, with 0 being black and 255 being white. It is usual to normalize the values to work with a range between 0.0 and 1.0.

# %%
x_train, x_test = x_train / 255.0, x_test / 255.0

# %% [markdown]
# We visualize a random image of the training set.

# %%
import numpy as np

i = np.random.randint(0, len(x_train))
plt.imshow(x_train[i], cmap='gray')
plt.show()

# %% [markdown]
# We reduce the dataset for  inducing more overfitting

# %%
from sklearn.model_selection import train_test_split
# split into train test sets
_, x, _, y = train_test_split(
    x_train, y_train, test_size=0.02, random_state=1, stratify=y_train)

num_classes = 10
from collections import Counter
x.shape, y.shape, Counter(y)
# Out:
# ((1200, 28, 28),
#  (1200,),
#  Counter({np.uint8(2): 119,
#           np.uint8(8): 117,
#           np.uint8(6): 118,
#           np.uint8(9): 119,
#           np.uint8(3): 123,
#           np.uint8(4): 117,
#           np.uint8(0): 119,
#           np.uint8(7): 125,
#           np.uint8(5): 108,
#           np.uint8(1): 135}))

# %% [markdown]
# #### What is Overfitting?
#
# **Overfitting** occurs when a model learns the training data too well, including its noise and random fluctuations, rather than the underlying pattern. The model performs well on training data but poorly on unseen data. The goal is not to fit the training set perfectly, but to **generalize** to new data.
#
# #### Why do we need to use regularization?
#
# We are going to assign the classes randomly to each image with random shuffle.

# %%
y_shuffle = np.copy(y)
np.random.shuffle(y_shuffle)
y[:5], y_shuffle[:5]
# Out:
# (array([2, 8, 6, 9, 3], dtype=uint8), array([1, 7, 2, 7, 7], dtype=uint8))

# %%
fig, axes = plt.subplots(3, 3, figsize=(9, 9))
axes = axes.ravel()

for i in np.arange(0, 9):
    ind = np.random.randint(len(y_shuffle))
    axes[i].imshow(x[ind].reshape(28, 28))
    axes[i].set_title(
        f"Digit = {y_shuffle[ind]}")
    axes[i].axis('off')

plt.subplots_adjust(wspace=0.3)

# %% [markdown]
# Lets build a model for learning the new random classes

# %%
# Input
inputs = tf.keras.Input(shape=(28, 28))
# Convert the 2D image to a vector
flat = layers.Flatten()(inputs)

# hidden layer 1
l_1 = layers.Dense(64, activation='relu')(flat)
# hidden layer 2
l_2 = layers.Dense(64, activation='relu')(l_1)
# hidden layer 3
l_3 = layers.Dense(64, activation='relu')(l_2)

# Outputs
outputs = layers.Dense(10, activation='softmax')(l_3)

# Model definition
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
history = model.fit(
    x,
    y_shuffle,
    batch_size=64,
    epochs=100,
    shuffle=True
)
# Out:
# Epoch 1/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.1033 - loss: 2.3087
# Epoch 2/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1683 - loss: 2.2668
# Epoch 3/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2125 - loss: 2.2271
# Epoch 4/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2492 - loss: 2.1784
# Epoch 5/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2708 - loss: 2.1222
# Epoch 6/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2958 - loss: 2.0488
# Epoch 7/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3450 - loss: 1.9704
# Epoch 8/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3492 - loss: 1.8840
# Epoch 9/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3933 - loss: 1.7857
# Epoch 10/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4433 - loss: 1.6794
# Epoch 11/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4883 - loss: 1.5623
# Epoch 12/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5308 - loss: 1.4451
# Epoch 13/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5833 - loss: 1.3234
# Epoch 14/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6425 - loss: 1.1992
# Epoch 15/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6917 - loss: 1.0856
# Epoch 16/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7317 - loss: 0.9810
# Epoch 17/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7567 - loss: 0.8874
# Epoch 18/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7617 - loss: 0.8304
# Epoch 19/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7592 - loss: 0.8083
# Epoch 20/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7325 - loss: 0.8328
# Epoch 21/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7192 - loss: 0.8834
# Epoch 22/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7508 - loss: 0.7936
# Epoch 23/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8192 - loss: 0.6249
# Epoch 24/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8900 - loss: 0.4768
# Epoch 25/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9158 - loss: 0.4113
# Epoch 26/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9300 - loss: 0.3647
# Epoch 27/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9342 - loss: 0.3308
# Epoch 28/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9400 - loss: 0.3055
# Epoch 29/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9425 - loss: 0.2865
# Epoch 30/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9500 - loss: 0.2742
# Epoch 31/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9550 - loss: 0.2652
# Epoch 32/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9550 - loss: 0.2597
# Epoch 33/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9417 - loss: 0.2767
# Epoch 34/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9250 - loss: 0.3115
# Epoch 35/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9008 - loss: 0.3612
# Epoch 36/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8592 - loss: 0.4594
# Epoch 37/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8550 - loss: 0.4399
# Epoch 38/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8867 - loss: 0.3789
# Epoch 39/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9000 - loss: 0.3387
# Epoch 40/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9292 - loss: 0.2752
# Epoch 41/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9175 - loss: 0.2785
# Epoch 42/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9333 - loss: 0.2442
# Epoch 43/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9567 - loss: 0.2078
# Epoch 44/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9683 - loss: 0.1567
# Epoch 45/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9783 - loss: 0.1270
# Epoch 46/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9758 - loss: 0.1221
# Epoch 47/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9758 - loss: 0.1289
# Epoch 48/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9808 - loss: 0.1240
# Epoch 49/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9817 - loss: 0.1209
# Epoch 50/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9808 - loss: 0.1251
# Epoch 51/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9767 - loss: 0.1348
# Epoch 52/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9717 - loss: 0.1497
# Epoch 53/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9592 - loss: 0.1646
# Epoch 54/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9525 - loss: 0.1694
# Epoch 55/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9417 - loss: 0.1796
# Epoch 56/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9475 - loss: 0.1836
# Epoch 57/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9317 - loss: 0.2212
# Epoch 58/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9408 - loss: 0.1996
# Epoch 59/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9708 - loss: 0.1174
# Epoch 60/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9733 - loss: 0.1138
# Epoch 61/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9775 - loss: 0.0981
# Epoch 62/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9742 - loss: 0.1065
# Epoch 63/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9642 - loss: 0.1266
# Epoch 64/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9600 - loss: 0.1582
# Epoch 65/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9450 - loss: 0.1753
# Epoch 66/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9442 - loss: 0.1833
# Epoch 67/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9750 - loss: 0.1305
# Epoch 68/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9842 - loss: 0.0712
# Epoch 69/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9933 - loss: 0.0424
# Epoch 70/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9992 - loss: 0.0301
# Epoch 71/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9983 - loss: 0.0252
# Epoch 72/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9992 - loss: 0.0195
# Epoch 73/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0164
# Epoch 74/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0148
# Epoch 75/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0138
# Epoch 76/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0130
# Epoch 77/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0123
# Epoch 78/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0117
# Epoch 79/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0111
# Epoch 80/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0107
# Epoch 81/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0102
# Epoch 82/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0098
# Epoch 83/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0094
# Epoch 84/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0090
# Epoch 85/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0087
# Epoch 86/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0084
# Epoch 87/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0081
# Epoch 88/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0078
# Epoch 89/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0076
# Epoch 90/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0073
# Epoch 91/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0071
# Epoch 92/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0068
# Epoch 93/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0066
# Epoch 94/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0064
# Epoch 95/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0062
# Epoch 96/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0061
# Epoch 97/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0059
# Epoch 98/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0057
# Epoch 99/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0056
# Epoch 100/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0054

# %%
results = model.evaluate(x, y_shuffle, verbose=0)
print('Train Accuracy: {}'.format(results[1]))
# Out:
# Train Accuracy: 1.0

# %%
fig, axes = plt.subplots(3, 3, figsize=(9, 9))
axes = axes.ravel()

for i in np.arange(0, 9):
    ind = np.random.randint(len(y_shuffle))
    pred_pobs = model.predict(np.expand_dims(x[ind], 0)).flatten()
    pred_class = np.argmax(pred_pobs)
    prob = np.max(pred_pobs)
    axes[i].imshow(x[ind].reshape(28, 28))
    axes[i].set_title(
        f"Digit = {y_shuffle[ind]} \n Prediction={pred_class} , Prob={prob:.4f}")
    axes[i].axis('off')

plt.subplots_adjust(wspace=0.5)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step

# %% [markdown]
# We can see that the model has fully fitted the training set. It practically does not matter what data you introduce into the neural network, it will almost always fit. The objective is not to fit the training set, it is to **GENERALIZE**.

# %% [markdown]
# #### Regularization for preventing overfitting
#
# To get the model to **generalize**, we can use one of the numerous regularization techniques

# %% [markdown]
# We build a model consisting of:
#
# - Input with dimension (28,28)
# - Flatten layer
# - Dense hidden  layer with 256 neurons and ReLU as activation function
# - Second dense hidden layer with 128 neurons and ReLU as activation function
# - Third dense  hidden layer with 128 neurons and ReLU as activation function
# - Output layer with 10 neurons and softmax activation (one per class).

# %%
# Input
inputs = tf.keras.Input(shape=(28,28), name='input_layer')
# Convert the 2D image to a vector
flat = layers.Flatten()(inputs)

# hidden layer 1
l_1 = layers.Dense(256, activation='relu', name='layer_1')(flat)
# hidden layer 2
l_2 = layers.Dense(128, activation='relu', name='layer_2')(l_1)
# hidden layer 3
l_3 = layers.Dense(128, activation='relu', name='layer_3')(l_2)

# Outputs
outputs = layers.Dense(num_classes, activation='softmax', name='output_layer')(l_3)

# Model definition
model = keras.Model(inputs=inputs, outputs=outputs, name='dont_overfit_model')

# %%
model.summary()
# Out:
# Model: "dont_overfit_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 28, 28)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_1 (Dense)                 │ (None, 256)            │       200,960 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_2 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_3 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_layer (Dense)            │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 251,658 (983.04 KB)
#  Trainable params: 251,658 (983.04 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# We define the following configuration for training:
# - **optimizer**: adam
# - **loss function**: sparse categorical crossentropy (for multi-class classification with integer labels)
# - **metrics**: accuracy

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
history = model.fit(
    x,
    y,
    batch_size=64,
    epochs=100,
    validation_split=0.2,
    shuffle=True
)
# Out:
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.4865 - loss: 1.8180 - val_accuracy: 0.8167 - val_loss: 1.0381
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8083 - loss: 0.6987 - val_accuracy: 0.8625 - val_loss: 0.4957
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9031 - loss: 0.3384 - val_accuracy: 0.8750 - val_loss: 0.4066
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9292 - loss: 0.2163 - val_accuracy: 0.8792 - val_loss: 0.4141
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9656 - loss: 0.1550 - val_accuracy: 0.8542 - val_loss: 0.4830
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9740 - loss: 0.1220 - val_accuracy: 0.8875 - val_loss: 0.4218
# Epoch 7/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9750 - loss: 0.1129 - val_accuracy: 0.8750 - val_loss: 0.3685
# Epoch 8/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9698 - loss: 0.0946 - val_accuracy: 0.8792 - val_loss: 0.4425
# Epoch 9/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9740 - loss: 0.0802 - val_accuracy: 0.8667 - val_loss: 0.4659
# Epoch 10/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9844 - loss: 0.0607 - val_accuracy: 0.8917 - val_loss: 0.4118
# Epoch 11/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9802 - loss: 0.0666 - val_accuracy: 0.9000 - val_loss: 0.3489
# Epoch 12/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9812 - loss: 0.0612 - val_accuracy: 0.8833 - val_loss: 0.4165
# Epoch 13/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9937 - loss: 0.0301 - val_accuracy: 0.8917 - val_loss: 0.4181
# Epoch 14/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9958 - loss: 0.0205 - val_accuracy: 0.9000 - val_loss: 0.3962
# Epoch 15/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9969 - loss: 0.0147 - val_accuracy: 0.8958 - val_loss: 0.4281
# Epoch 16/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0076 - val_accuracy: 0.9000 - val_loss: 0.3854
# Epoch 17/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 0.9042 - val_loss: 0.3992
# Epoch 18/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.9000 - val_loss: 0.4031
# Epoch 19/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0
# Epoch 68/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 1.6644e-04 - val_accuracy: 0.8875 - val_loss: 0.4851
# Epoch 69/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 1.6063e-04 - val_accuracy: 0.8917 - val_loss: 0.4862
# Epoch 70/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 1.5521e-04 - val_accuracy: 0.8917 - val_loss: 0.4875
# Epoch 71/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 1.4999e-04 - val_accuracy: 0.8917 - val_loss: 0.4886
# Epoch 72/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 1.4502e-04 - val_accuracy: 0.8917 - val_loss: 0.4898
# Epoch 73/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 1.4028e-04 - val_accuracy: 0.8958 - val_loss: 0.4909
# Epoch 74/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 1.3573e-04 - val_accuracy: 0.8958 - val_loss: 0.4923
# Epoch 75/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 1.3142e-04 - val_accuracy: 0.8958 - val_loss: 0.4935
# Epoch 76/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 1.2727e-04 - val_accuracy: 0.8958 - val_loss: 0.4947
# Epoch 77/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 1.2329e-04 - val_accuracy: 0.8958 - val_loss: 0.4957
# Epoch 78/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 1.1949e-04 - val_accuracy: 0.8958 - val_loss: 0.4971
# Epoch 79/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 1.1584e-04 - val_accuracy: 0.8958 - val_loss: 0.4981
# Epoch 80/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 1.1233e-04 - val_accuracy: 0.8958 - val_loss: 0.4991
# Epoch 81/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 1.0898e-04 - val_accuracy: 0.8958 - val_loss: 0.5001
# Epoch 82/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 1.0575e-04 - val_accuracy: 0.8958 - val_loss: 0.5013
# Epoch 83/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 1.0269e-04 - val_accuracy: 0.8958 - val_loss: 0.5021
# Epoch 84/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 9.9733e-05 - val_accuracy: 0.8958 - val_loss: 0.5032
# Epoch 85/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 9.6886e-05 - val_accuracy: 0.8958 - val_loss: 0.5041
# Epoch 86/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 9.4162e-05 - val_accuracy: 0.8958 - val_loss: 0.5049
# Epoch 87/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 9.1528e-05 - val_accuracy: 0.8958 - val_loss: 0.5060
# Epoch 88/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 8.9007e-05 - val_accuracy: 0.8958 - val_loss: 0.5071
# Epoch 89/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 8.6575e-05 - val_accuracy: 0.8958 - val_loss: 0.5078
# Epoch 90/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 8.4240e-05 - val_accuracy: 0.8958 - val_loss: 0.5089
# Epoch 91/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 8.1997e-05 - val_accuracy: 0.8958 - val_loss: 0.5097
# Epoch 92/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 7.9838e-05 - val_accuracy: 0.8958 - val_loss: 0.5108
# Epoch 93/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 7.7735e-05 - val_accuracy: 0.8958 - val_loss: 0.5113
# Epoch 94/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 7.5734e-05 - val_accuracy: 0.8958 - val_loss: 0.5126
# Epoch 95/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 7.3778e-05 - val_accuracy: 0.8958 - val_loss: 0.5133
# Epoch 96/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 7.1895e-05 - val_accuracy: 0.8958 - val_loss: 0.5142
# Epoch 97/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 7.0064e-05 - val_accuracy: 0.8958 - val_loss: 0.5148
# Epoch 98/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 6.8307e-05 - val_accuracy: 0.8958 - val_loss: 0.5159
# Epoch 99/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 6.6620e-05 - val_accuracy: 0.8958 - val_loss: 0.5168
# Epoch 100/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 6.4950e-05 - val_accuracy: 0.8958 - val_loss: 0.5178

# %%
results = model.evaluate(x_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
# Out:
# Test Loss: 0.5643723011016846
# Test Accuracy: 0.9075000286102295

# %% [markdown]
# We visualize the evolution of the values in each epoch of the loss function and accuracy.

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch

# %%
hist.head()
# Out:
#    accuracy      loss  val_accuracy  val_loss  epoch
# 0  0.486458  1.817984      0.816667  1.038128      0
# 1  0.808333  0.698660      0.862500  0.495683      1
# 2  0.903125  0.338428      0.875000  0.406614      2
# 3  0.929167  0.216328      0.879167  0.414062      3
# 4  0.965625  0.155007      0.854167  0.483010      4

# %% [markdown]
# <a id='overfitting_results'></a>
# When interpreting both graphs, it is evident that the model over-fits the training values and is not able to generalize well for the validation values. **It is a clear example of overfitting**.
#
# The following function will be useful throughout the different practical examples.

# %%
def show_samples(x_test, y_test, model):
    """Display a grid of sample predictions with correct (green) and incorrect (red) labels."""
    predictions = model.predict(x_test)
    predicted_classes = np.argmax(predictions, -1)

    L = 5
    W = 5
    fig, axes = plt.subplots(L, W, figsize=(14, 14))
    axes = axes.ravel()

    for i in np.arange(0, L * W):
        ind = np.random.randint(len(y_test))
        axes[i].imshow(x_test[ind].reshape(28, 28))
        prob_pred = np.max(predictions[ind, :])
        class_pred = int(predicted_classes[ind])
        original_class = int(y_test[ind])
        if class_pred == original_class:
            color = 'green'
        else:
            color = 'red'
        title = "Pred: {0} \n Target: {1} \n Prob: {2:.3f}".format(
        class_pred, original_class, prob_pred)
        axes[i].set_title(title, color=color)
        axes[i].axis('off')

    plt.subplots_adjust(wspace=0.5)

# %%
plot_history(history)

# %%
results = model.evaluate(x_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
# Out:
# Test Loss: 0.5643723011016846
# Test Accuracy: 0.9075000286102295

# %%
show_samples(x_test, y_test, model)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %% [markdown]
# ## Create a simpler model
#
# The simplest way to prevent overfitting is to create  a simple model: A model with less number of  parameters (which is determined by the number of layers and the number of units per layer).
#
# A more complex model with more parameters will have much more capacity and will be able to learn almost any training set. Deep learning models tend to be good at fitting to the training data, but the real challenge is generalization, not fitting.

# %%
# Input layer
inputs = tf.keras.Input(shape=(28, 28), name='input_layer')
flat = layers.Flatten()(inputs)

# First hidden layer
l_1 = layers.Dense(8, activation='relu', name='layer_1')(flat)

# Output layer
outputs = layers.Dense(num_classes, activation='softmax',
                       name='output_layer')(l_1)
model_simpler = keras.Model(
    inputs=inputs, outputs=outputs, name='simpler_model')

model_simpler.summary()
# Out:
# Model: "simpler_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 28, 28)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_1 (Dense)                 │ (None, 8)              │         6,280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_layer (Dense)            │ (None, 10)             │            90 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,370 (24.88 KB)
#  Trainable params: 6,370 (24.88 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_simpler.compile(optimizer='adam',
                      loss='sparse_categorical_crossentropy',
                      metrics=['accuracy'])
history_simpler = model_simpler.fit(x,
                                    y,
                                    batch_size=64,
                                    epochs=100,
                                    validation_split=0.2,
                                    shuffle=True)
# Out:
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.1354 - loss: 2.2435 - val_accuracy: 0.2083 - val_loss: 2.1372
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2625 - loss: 2.0387 - val_accuracy: 0.3000 - val_loss: 1.9706
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3500 - loss: 1.8518 - val_accuracy: 0.3417 - val_loss: 1.8173
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4125 - loss: 1.6986 - val_accuracy: 0.4083 - val_loss: 1.6965
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4708 - loss: 1.5707 - val_accuracy: 0.4750 - val_loss: 1.5887
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5396 - loss: 1.4592 - val_accuracy: 0.5625 - val_loss: 1.4886
# Epoch 7/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6042 - loss: 1.3527 - val_accuracy: 0.6083 - val_loss: 1.3842
# Epoch 8/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6594 - loss: 1.2423 - val_accuracy: 0.6333 - val_loss: 1.2697
# Epoch 9/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7031 - loss: 1.1313 - val_accuracy: 0.6833 - val_loss: 1.1635
# Epoch 10/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7521 - loss: 1.0289 - val_accuracy: 0.7167 - val_loss: 1.0678
# Epoch 11/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.
# Epoch 87/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9948 - loss: 0.0801 - val_accuracy: 0.8792 - val_loss: 0.4647
# Epoch 88/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9958 - loss: 0.0785 - val_accuracy: 0.8792 - val_loss: 0.4654
# Epoch 89/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9958 - loss: 0.0768 - val_accuracy: 0.8792 - val_loss: 0.4656
# Epoch 90/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9969 - loss: 0.0753 - val_accuracy: 0.8792 - val_loss: 0.4661
# Epoch 91/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9969 - loss: 0.0738 - val_accuracy: 0.8792 - val_loss: 0.4671
# Epoch 92/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9979 - loss: 0.0722 - val_accuracy: 0.8792 - val_loss: 0.4671
# Epoch 93/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9990 - loss: 0.0708 - val_accuracy: 0.8792 - val_loss: 0.4676
# Epoch 94/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9990 - loss: 0.0693 - val_accuracy: 0.8792 - val_loss: 0.4681
# Epoch 95/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9990 - loss: 0.0680 - val_accuracy: 0.8792 - val_loss: 0.4686
# Epoch 96/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9990 - loss: 0.0666 - val_accuracy: 0.8833 - val_loss: 0.4692
# Epoch 97/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9990 - loss: 0.0653 - val_accuracy: 0.8833 - val_loss: 0.4703
# Epoch 98/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9990 - loss: 0.0640 - val_accuracy: 0.8833 - val_loss: 0.4707
# Epoch 99/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9990 - loss: 0.0627 - val_accuracy: 0.8833 - val_loss: 0.4709
# Epoch 100/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9990 - loss: 0.0615 - val_accuracy: 0.8833 - val_loss: 0.4719

# %%
plot_history(history_simpler)

# %%
results = model_simpler.evaluate(x_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
# Out:
# Test Loss: 0.517562985420227
# Test Accuracy: 0.8654000163078308

# %% [markdown]
# ## Reduce batch_size
#
# Other method is decreasing the `batch_size`during the gradient descend to add more uncertainty to the estimation of the parameter gradients, thus reducing the capacity of the model

# %%
# Input
inputs = tf.keras.Input(shape=(28,28), name='input_layer')
# Convert the 2D image to a vector
flat = layers.Flatten()(inputs)

# hidden layer 1
l_1 = layers.Dense(256, activation='relu', name='layer_1')(flat)
# hidden layer 2
l_2 = layers.Dense(128, activation='relu', name='layer_2')(l_1)
# hidden layer 3
l_3 = layers.Dense(128, activation='relu', name='layer_3')(l_2)

# Outputs
outputs = layers.Dense(num_classes, activation='softmax', name='output_layer')(l_3)

# Model definition
model = keras.Model(inputs=inputs, outputs=outputs, name='dont_overfit_model')
## same model
model.summary()
# Out:
# Model: "dont_overfit_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 28, 28)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_1 (Dense)                 │ (None, 256)            │       200,960 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_2 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_3 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_layer (Dense)            │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 251,658 (983.04 KB)
#  Trainable params: 251,658 (983.04 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
history_2 = model.fit(
    x,
    y,
    batch_size=16,
    epochs=100,
    validation_split=0.2,
    shuffle=True
)
# Out:
# Epoch 1/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.6156 - loss: 1.2524 - val_accuracy: 0.8500 - val_loss: 0.5174
# Epoch 2/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8656 - loss: 0.4079 - val_accuracy: 0.8583 - val_loss: 0.4521
# Epoch 3/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9312 - loss: 0.2203 - val_accuracy: 0.8875 - val_loss: 0.3696
# Epoch 4/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9677 - loss: 0.1160 - val_accuracy: 0.8917 - val_loss: 0.4001
# Epoch 5/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9875 - loss: 0.0627 - val_accuracy: 0.8833 - val_loss: 0.3891
# Epoch 6/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9937 - loss: 0.0342 - val_accuracy: 0.8875 - val_loss: 0.4061
# Epoch 7/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9948 - loss: 0.0231 - val_accuracy: 0.8833 - val_loss: 0.4748
# Epoch 8/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9979 - loss: 0.0119 - val_accuracy: 0.8875 - val_loss: 0.4692
# Epoch 9/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0084 - val_accuracy: 0.8917 - val_loss: 0.4761
# Epoch 10/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.9000 - val_loss: 0.4847
# Epoch 11/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.9000 - val_loss: 0.4795
# Epoch 12/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.8833 - val_loss: 0.5117
# Epoch 13/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.9042 - val_loss: 0.4809
# Epoch 14/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 9.3747e-04 - val_accuracy: 0.9042 - val_loss: 0.4801
# Epoch 15/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 6.9926e-04 - val_accuracy: 0.9000 - val_loss: 0.4840
# Epoch 16/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 5.6704e-04 - val_accuracy: 0.9000 - val_loss: 0.4895
# Epoch 17/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 4.8719e-04 - val_accuracy: 0.9042 - val_loss: 0.4960
# Epoch 18/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 4.2684e-04 - val_accuracy: 0.9042 - val_loss: 0.5011
# Epoch 19/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 3.7772e-04 - val_accuracy: 0.9042 - val_loss: 0.5067
# Epoch 20/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 3.3735e-04 - val_accuracy: 0.9042 - val_loss: 0.5104
# Epoch 21/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 3.0294e-04 - val_accuracy: 0.9042 - val_loss: 0.5134
# Epoch 22/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 2.7272e-04 - val_accuracy: 0.9042 - val_loss: 0.5169
# Epoch 23/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 2.4644e-04 - val_accuracy: 0.9042 - val_loss: 0.5201
# Epoch 24/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 2.2290e-04 - val_accuracy: 0.9000 - val_loss: 0.5232
# Epoch 25/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 2.0085e-04 - val_accuracy: 0.9000 - val_loss: 0.5278
# Epoch 26/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.8149e-04 - val_accuracy: 0.9000 - val_loss: 0.5332
# Epoch 27/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.6503e-04 - val_accuracy: 0.9000 - val_loss: 0.5382
# Epoch 28/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.5108e-04 - val_accuracy: 0.9042 - val_loss: 0.5427
# Epoch 29/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.3857e-04 - val_accuracy: 0.9083 - val_loss: 0.5466
# Epoch 30/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.2739e-04 - val_accuracy: 0.9083 - val_loss: 0.5507
# Epoch 31/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 1.1735e-04 - val_accuracy: 0.9083 - val_loss: 0.5542
# Epoch 32/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 1.0000 - loss: 1.0830e-04 - val_accuracy: 0.9083 - val_loss: 0.5579
# Epoch 33/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 1.0003e-04 - val_accuracy: 0.9083 - val_loss: 0.5618
# Epoch 34/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 9.2680e-05 - val_accuracy: 0.9083 - val_loss: 0.5648
# Epoch 35/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 1.0000 - loss: 8.5930e-05 - val_accuracy: 0.9083 - val_loss: 0.5679
# Epoch 36/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 7.9821e-05 - val_accuracy: 0.9083 - val_loss: 0.5711
# Epoch 37/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 7.4234e-05 - val_accuracy: 0.9083 - val_loss: 0.5743
# Epoch 38/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 6.9151e-05 - val_accuracy: 0.9083 - val_loss: 0.5772
# Epoch 39/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 6.4475e-05 - val_accuracy: 0.9083 - val_loss: 0.5800
# Epoch 40/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 6.0195e-05 - val_accuracy: 0.9042 - val_loss: 0.5828
# Epoch 41/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 5.6161e-05 - val_accuracy: 0.9042 - val_loss: 0.5852
# Epoch 42/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 5.2539e-05 - val_accuracy: 0.9042 - val_loss: 0.5883
# Epoch 43/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 4.9120e-05 - val_accuracy: 0.9042 - val_loss: 0.5914
# Epoch 44/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 4.6055e-05 - val_accuracy: 0.9042 - val_loss: 0.5938
# Epoch 45/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 4.3154e-05 - val_accuracy: 0.9042 - val_loss: 0.5956
# Epoch 46/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 4.0546e-05 - val_accuracy: 0.9042 - val_loss: 0.5987
# Epoch 47/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 3.8091e-05 - val_accuracy: 0.9042 - val_loss: 0.6011
# Epoch 48/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 3.5765e-05 - val_accuracy: 0.9042 - val_loss: 0.6027
# Epoch 49/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 3.3576e-05 - val_accuracy: 0.9042 - val_loss: 0.6053
# Epoch 50/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 3.1577e-05 - val_accuracy: 0.9042 - val_loss: 0.6083
# Epoch 51/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 2.9641e-05 - val_accuracy: 0.9042 - val_loss: 0.6108
# Epoch 52/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 2.7937e-05 - val_accuracy: 0.9042 - val_loss: 0.6132
# Epoch 53/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 2.6328e-05 - val_accuracy: 0.9042 - val_loss: 0.6165
# Epoch 54/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 1.0000 - loss: 2.4794e-05 - val_accuracy: 0.9042 - val_loss: 0.6193
# Epoch 55/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 2.3398e-05 - val_accuracy: 0.9042 - val_loss: 0.6214
# Epoch 56/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 2.2083e-05 - val_accuracy: 0.9042 - val_loss: 0.6242
# Epoch 57/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 2.0876e-05 - val_accuracy: 0.9042 - val_loss: 0.6259
# Epoch 58/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.9743e-05 - val_accuracy: 0.9042 - val_loss: 0.6291
# Epoch 59/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.8693e-05 - val_accuracy: 0.9042 - val_loss: 0.6314
# Epoch 60/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 1.7718e-05 - val_accuracy: 0.9042 - val_loss: 0.6341
# Epoch 61/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 1.0000 - loss: 1.6776e-05 - val_accuracy: 0.9042 - val_loss: 0.6363
# Epoch 62/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 1.5930e-05 - val_accuracy: 0.9042 - val_loss: 0.6390
# Epoch 63/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 1.5119e-05 - val_accuracy: 0.9042 - val_loss: 0.6412
# Epoch 64/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 1.4325e-05 - val_accuracy: 0.9042 - val_loss: 0.6442
# Epoch 65/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.3598e-05 - val_accuracy: 0.9042 - val_loss: 0.6458
# Epoch 66/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.2916e-05 - val_accuracy: 0.9042 - val_loss: 0.6480
# Epoch 67/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 1.2260e-05 - val_accuracy: 0.9042 - val_loss: 0.6506
# Epoch 68/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.1658e-05 - val_accuracy: 0.9042 - val_loss: 0.6531
# Epoch 69/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.1093e-05 - val_accuracy: 0.9042 - val_loss: 0.6555
# Epoch 70/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.0599e-05 - val_accuracy: 0.9042 - val_loss: 0.6565
# Epoch 71/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.0021e-05 - val_accuracy: 0.9083 - val_loss: 0.6588
# Epoch 72/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 9.4885e-06 - val_accuracy: 0.9083 - val_loss: 0.6615
# Epoch 73/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 8.9702e-06 - val_accuracy: 0.9083 - val_loss: 0.6637
# Epoch 74/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 8.5071e-06 - val_accuracy: 0.9083 - val_loss: 0.6654
# Epoch 75/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 8.0613e-06 - val_accuracy: 0.9083 - val_loss: 0.6692
# Epoch 76/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 7.6560e-06 - val_accuracy: 0.9083 - val_loss: 0.6718
# Epoch 77/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 7.2751e-06 - val_accuracy: 0.9083 - val_loss: 0.6741
# Epoch 78/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 6.9141e-06 - val_accuracy: 0.9083 - val_loss: 0.6762
# Epoch 79/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 6.5571e-06 - val_accuracy: 0.9083 - val_loss: 0.6794
# Epoch 80/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 6.2497e-06 - val_accuracy: 0.9083 - val_loss: 0.6816
# Epoch 81/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 5.9515e-06 - val_accuracy: 0.9083 - val_loss: 0.6839
# Epoch 82/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 5.6558e-06 - val_accuracy: 0.9083 - val_loss: 0.6868
# Epoch 83/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 5.3900e-06 - val_accuracy: 0.9083 - val_loss: 0.6889
# Epoch 84/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 5.1332e-06 - val_accuracy: 0.9083 - val_loss: 0.6917
# Epoch 85/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 4.8981e-06 - val_accuracy: 0.9083 - val_loss: 0.6940
# Epoch 86/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 4.6731e-06 - val_accuracy: 0.9083 - val_loss: 0.6961
# Epoch 87/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 4.4600e-06 - val_accuracy: 0.9083 - val_loss: 0.6984
# Epoch 88/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 4.2520e-06 - val_accuracy: 0.9083 - val_loss: 0.7006
# Epoch 89/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 1.0000 - loss: 4.0549e-06 - val_accuracy: 0.9083 - val_loss: 0.7028
# Epoch 90/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 3.8725e-06 - val_accuracy: 0.9083 - val_loss: 0.7052
# Epoch 91/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 3.7049e-06 - val_accuracy: 0.9083 - val_loss: 0.7076
# Epoch 92/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 3.5315e-06 - val_accuracy: 0.9083 - val_loss: 0.7105
# Epoch 93/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 3.3745e-06 - val_accuracy: 0.9083 - val_loss: 0.7130
# Epoch 94/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 3.2350e-06 - val_accuracy: 0.9083 - val_loss: 0.7149
# Epoch 95/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 3.0865e-06 - val_accuracy: 0.9083 - val_loss: 0.7174
# Epoch 96/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 2.9570e-06 - val_accuracy: 0.9083 - val_loss: 0.7201
# Epoch 97/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 2.8285e-06 - val_accuracy: 0.9083 - val_loss: 0.7220
# Epoch 98/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 2.7126e-06 - val_accuracy: 0.9083 - val_loss: 0.7245
# Epoch 99/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 2.5940e-06 - val_accuracy: 0.9083 - val_loss: 0.7262
# Epoch 100/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 2.4771e-06 - val_accuracy: 0.9083 - val_loss: 0.7288

# %%
plot_history(history_2)

# %%
results = model.evaluate(x_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
# Out:
# Test Loss: 1.0227296352386475
# Test Accuracy: 0.9185000061988831

# %% [markdown]
# ### Question 1:
# #### What differences do you see if you change the batch_size to a lower or higher value? For example to 1 and to 512

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
history_3 = model.fit(
    x,
    y,
    batch_size=16,
    epochs=100,
    validation_split=0.2,
    shuffle=True
)
plot_history(history_3)
# Out:
# Epoch 1/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9125 - val_loss: 1.1635
# Epoch 2/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9125 - val_loss: 1.1637
# Epoch 3/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9125 - val_loss: 1.1640
# Epoch 4/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9125 - val_loss: 1.1643
# Epoch 5/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9125 - val_loss: 1.1647
# Epoch 6/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1651
# Epoch 7/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1656
# Epoch 8/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1660
# Epoch 9/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1665
# Epoch 10/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1671
# Epoch 11/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1676
# Epoch 12/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1682
# Epoch 13/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1687
# Epoch 14/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1693
# Epoch 15/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1699
# Epoch 16/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1705
# Epoch 17/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1711
# Epoch 18/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1717
# Epoch 19/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1723
# Epoch 20/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1729
# Epoch 21/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1736
# Epoch 22/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1742
# Epoch 23/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1748
# Epoch 24/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1754
# Epoch 25/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1760
# Epoch 26/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1766
# Epoch 27/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1773
# Epoch 28/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1779
# Epoch 29/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1785
# Epoch 30/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1791
# Epoch 31/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1797
# Epoch 32/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1804
# Epoch 33/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1810
# Epoch 34/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1816
# Epoch 35/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1822
# Epoch 36/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1828
# Epoch 37/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1834
# Epoch 38/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1840
# Epoch 39/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1846
# Epoch 40/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1852
# Epoch 41/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1858
# Epoch 42/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1864
# Epoch 43/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1870
# Epoch 44/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1875
# Epoch 45/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1881
# Epoch 46/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1887
# Epoch 47/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1892
# Epoch 48/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1898
# Epoch 49/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1903
# Epoch 50/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1908
# Epoch 51/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1914
# Epoch 52/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1919
# Epoch 53/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1924
# Epoch 54/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1930
# Epoch 55/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1935
# Epoch 56/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1940
# Epoch 57/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1945
# Epoch 58/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1950
# Epoch 59/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1955
# Epoch 60/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1960
# Epoch 61/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1965
# Epoch 62/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1970
# Epoch 63/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1975
# Epoch 64/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1980
# Epoch 65/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1984
# Epoch 66/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1989
# Epoch 67/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1994
# Epoch 68/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.1998
# Epoch 69/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.2003
# Epoch 70/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.2007
# Epoch 71/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.2012
# Epoch 72/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.2016
# Epoch 73/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.2020
# Epoch 74/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.2025
# Epoch 75/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.2029
# Epoch 76/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.2033
# Epoch 77/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.2038
# Epoch 78/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.2042
# Epoch 79/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.2046
# Epoch 80/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.2050
# Epoch 81/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.2054
# Epoch 82/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.2058
# Epoch 83/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.2062
# Epoch 84/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.2067
# Epoch 85/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.2071
# Epoch 86/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.2075
# Epoch 87/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.2079
# Epoch 88/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.2083
# Epoch 89/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.2087
# Epoch 90/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.2091
# Epoch 91/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.2095
# Epoch 92/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.2099
# Epoch 93/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.2103
# Epoch 94/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.2106
# Epoch 95/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.2110
# Epoch 96/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.2114
# Epoch 97/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.2118
# Epoch 98/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.2122
# Epoch 99/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.2125
# Epoch 100/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9167 - val_loss: 1.2129

# %% [markdown]
# <a id='dropout'></a>
# ## Dropout
#
# [Dropout](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dropout) is a regularization technique that randomly "drops" (sets to zero) a fraction of neurons during training.
#
# **How it works:**
# 1. During training, each neuron has a probability `p` (dropout rate) of being temporarily removed
# 2. The remaining neurons' outputs are scaled by `1/(1-p)` to maintain expected values
# 3. During inference, all neurons are used (no dropout applied)
#
# **Why it works:**
# - Prevents neurons from co-adapting (relying too much on specific other neurons)
# - Forces the network to learn redundant representations
# - Acts like training an ensemble of different networks
#
# **Typical values:** 0.2 to 0.5 (higher = more regularization)
#
# ```python
# tf.keras.layers.Dropout(rate)
# ```
#
# With Functional API:
# ```python
# next_layer = layers.Dropout(0.4)(prev_layer)
# ```
# With Sequential:
# ```python
# model.add(layers.Dropout(0.4))
# ```

# %%
# Input
inputs = tf.keras.Input(shape=(28, 28), name='input_layer')
# Convert the 2D image to a vector
flat = layers.Flatten()(inputs)

flat = layers.Dropout(0.5, name='dropout_flat')(flat)
# hidden layer 1
l_1 = layers.Dense(256, activation='relu', name='layer_1')(flat)
l_1 = layers.Dropout(0.5, name='dropout_l1')(l_1)
# hidden layer 2
l_2 = layers.Dense(128, activation='relu', name='layer_2')(l_1)
l_2 = layers.Dropout(0.5, name='dropout_l2')(l_2)
# hidden layer 3
l_3 = layers.Dense(128, activation='relu', name='layer_3')(l_2)
l_3 = layers.Dropout(0.5, name='dropout_l3')(l_3)

# Outputs
outputs = layers.Dense(num_classes, activation='softmax',
                       name='output_layer')(l_3)


model_dropout = keras.Model(
    inputs=inputs, outputs=outputs, name='dont_overfit_model_dropout')

# %%
model_dropout.summary()
# Out:
# Model: "dont_overfit_model_dropout"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 28, 28)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_4 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_flat (Dropout)          │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_1 (Dense)                 │ (None, 256)            │       200,960 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_l1 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_2 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_l2 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_3 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_l3 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_layer (Dense)            │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 251,658 (983.04 KB)
#  Trainable params: 251,658 (983.04 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_dropout.compile(optimizer='adam',
                      loss='sparse_categorical_crossentropy',
                      metrics=['accuracy'])

# %%
history_dropout = model_dropout.fit(
    x,
    y,
    batch_size=64,
    epochs=100,
    validation_split=0.2,
    shuffle=True
)
# Out:
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.1073 - loss: 2.4483 - val_accuracy: 0.3250 - val_loss: 2.2258
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.1469 - loss: 2.2916 - val_accuracy: 0.4750 - val_loss: 2.1835
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1958 - loss: 2.2089 - val_accuracy: 0.6042 - val_loss: 2.0951
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2260 - loss: 2.1284 - val_accuracy: 0.6417 - val_loss: 1.9192
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.3010 - loss: 1.9743 - val_accuracy: 0.6750 - val_loss: 1.5907
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3948 - loss: 1.7868 - val_accuracy: 0.7208 - val_loss: 1.2710
# Epoch 7/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4427 - loss: 1.5987 - val_accuracy: 0.7667 - val_loss: 1.0728
# Epoch 8/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4740 - loss: 1.4646 - val_accuracy: 0.8042 - val_loss: 0.9253
# Epoch 9/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5292 - loss: 1.3635 - val_accuracy: 0.8042 - val_loss: 0.8037
# Epoch 10/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5792 - loss: 1.2302 - val_accuracy: 0.8167 - val_loss: 0.7461
# Epoch 11/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5844 - loss: 1.1937 - val_accuracy: 0.8208 - val_loss: 0.6688
# Epoch 12/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6250 - loss: 1.0439 - val_accuracy: 0.8417 - val_loss: 0.6220
# Epoch 13/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6333 - loss: 1.0500 - val_accuracy: 0.8333 - val_loss: 0.5828
# Epoch 14/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6667 - loss: 0.9793 - val_accuracy: 0.8250 - val_loss: 0.5580
# Epoch 15/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6875 - loss: 0.9430 - val_accuracy: 0.8250 - val_loss: 0.5306
# Epoch 16/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7042 - loss: 0.9213 - val_accuracy: 0.8417 - val_loss: 0.5331
# Epoch 17/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6896 - loss: 0.9159 - val_accuracy: 0.8458 - val_loss: 0.5095
# Epoch 18/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7104 - loss: 0.8427 - val_accuracy: 0.8542 - val_loss: 0.4844
# Epoch 19/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7427 - loss: 0.7764 - val_accuracy: 0.8708 - val_loss: 0.4742
# Epoch 20/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7344 - loss: 0.7639 - val_accuracy: 0.8667 - val_loss: 0.4486
# Epoch 21/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7510 - loss: 0.7326 - val_accuracy: 0.8792 - val_loss: 0.4462
# Epoch 22/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.
# Epoch 98/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9302 - loss: 0.2344 - val_accuracy: 0.9333 - val_loss: 0.3002
# Epoch 99/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9198 - loss: 0.2298 - val_accuracy: 0.9417 - val_loss: 0.3062
# Epoch 100/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9365 - loss: 0.1864 - val_accuracy: 0.9208 - val_loss: 0.3159

# %%
plot_history(history_dropout)

# %%
results = model_dropout.evaluate(x_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
# Out:
# Test Loss: 0.31390485167503357
# Test Accuracy: 0.920799970626831

# %% [markdown]
# ### Question 2:
# #### What happens if you change the dropout to 0.1 or 0.9? And what if you put it only on one layer?
# #### What happens if we delete the flatten first dropout?

# %%
# Input
inputs = tf.keras.Input(shape=(28, 28), name='input_layer')
# Convert the 2D image to a vector
flat = layers.Flatten()(inputs)

flat = layers.Dropout(0.5, name='dropout_flat')(flat)
# hidden layer 1
l_1 = layers.Dense(256, activation='relu', name='layer_1')(flat)
#l_1 = layers.Dropout(0.9, name='dropout_l1')(l_1)
# hidden layer 2
l_2 = layers.Dense(128, activation='relu', name='layer_2')(l_1)
#l_2 = layers.Dropout(0.9, name='dropout_l2')(l_2)
# hidden layer 3
l_3 = layers.Dense(128, activation='relu', name='layer_3')(l_2)
#l_3 = layers.Dropout(0.9, name='dropout_l3')(l_3)

# Outputs
outputs = layers.Dense(num_classes, activation='softmax',
                       name='output_layer')(l_3)


model_dropout = keras.Model(
    inputs=inputs, outputs=outputs, name='dont_overfit_model_dropout')
model_dropout.compile(optimizer='adam',
                      loss='sparse_categorical_crossentropy',
                      metrics=['accuracy'])
history_dropout = model_dropout.fit(
    x,
    y,
    batch_size=64,
    epochs=100,
    validation_split=0.2,
    shuffle=True
)
plot_history(history_dropout)
# Out:
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.3625 - loss: 2.0666 - val_accuracy: 0.6875 - val_loss: 1.5031
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6781 - loss: 1.1718 - val_accuracy: 0.8083 - val_loss: 0.6880
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7698 - loss: 0.6786 - val_accuracy: 0.8292 - val_loss: 0.5424
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8031 - loss: 0.5440 - val_accuracy: 0.8250 - val_loss: 0.4988
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8458 - loss: 0.4581 - val_accuracy: 0.8667 - val_loss: 0.4418
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8427 - loss: 0.4338 - val_accuracy: 0.8833 - val_loss: 0.4213
# Epoch 7/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8865 - loss: 0.3565 - val_accuracy: 0.9083 - val_loss: 0.3429
# Epoch 8/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8958 - loss: 0.3135 - val_accuracy: 0.9083 - val_loss: 0.3241
# Epoch 9/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8938 - loss: 0.2919 - val_accuracy: 0.8792 - val_loss: 0.3767
# Epoch 10/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9146 - loss: 0.2594 - val_accuracy: 0.8792 - val_loss: 0.3621
# Epoch 11/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9042 - loss: 0.2714 - val_accuracy: 0.8917 - val_loss: 0.3337
# Epoch 12/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9125 - loss: 0.2501 - val_accuracy: 0.9250 - val_loss: 0.2912
# Epoch 13/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9177 - loss: 0.2064 - val_accuracy: 0.9250 - val_loss: 0.2977
# Epoch 14/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9323 - loss: 0.1882 - val_accuracy: 0.9125 - val_loss: 0.3355
# Epoch 15/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9333 - loss: 0.2127 - val_accuracy: 0.9125 - val_loss: 0.3380
# Epoch 16/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9281 - loss: 0.2284 - val_accuracy: 0.9250 - val_loss: 0.3073
# Epoch 17/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9448 - loss: 0.1699 - val_accuracy: 0.9208 - val_loss: 0.3004
# Epoch 18/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9531 - loss: 0.1512 - val_accuracy: 0.9125 - val_loss: 0.2878
# Epoch 19/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.
# Epoch 95/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9844 - loss: 0.0352 - val_accuracy: 0.9333 - val_loss: 0.2753
# Epoch 96/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9917 - loss: 0.0261 - val_accuracy: 0.9458 - val_loss: 0.2800
# Epoch 97/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9917 - loss: 0.0277 - val_accuracy: 0.9292 - val_loss: 0.3244
# Epoch 98/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9906 - loss: 0.0330 - val_accuracy: 0.9458 - val_loss: 0.2867
# Epoch 99/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9896 - loss: 0.0356 - val_accuracy: 0.9250 - val_loss: 0.3245
# Epoch 100/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9875 - loss: 0.0259 - val_accuracy: 0.9542 - val_loss: 0.2759

# %%
results = model_dropout.evaluate(x_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
# Out:
# Test Loss: 0.36916497349739075
# Test Accuracy: 0.9236000180244446

# %% [markdown]
# ## Batch Normalization
#
# [Batch normalization](https://www.tensorflow.org/api_docs/python/tf/keras/layers/BatchNormalization) normalizes the inputs of each layer by adjusting and scaling the activations.
#
# **How it works:**
# 1. For each mini-batch, compute the mean and variance of the activations
# 2. Normalize: `x_norm = (x - mean) / sqrt(variance + epsilon)`
# 3. Scale and shift: `output = gamma * x_norm + beta` (learnable parameters)
#
# **Benefits:**
# - Reduces internal covariate shift (layer inputs change during training)
# - Allows higher learning rates
# - Acts as a regularizer (reduces need for dropout)
# - Makes training more stable
#
# **Note:** Behavior differs between training (uses batch statistics) and inference (uses running averages).
#
# With Functional API:
# ```python
# next_layer = layers.BatchNormalization()(prev_layer)
# ```
# With Sequential:
# ```python
# model.add(layers.BatchNormalization())
# ```

# %%
# Input
inputs = tf.keras.Input(shape=(28, 28), name='input_layer')
# Convert the 2D image to a vector
flat = layers.Flatten()(inputs)

# hidden layer 1
l_1 = layers.Dense(256, activation='relu', name='layer_1')(flat)
l_1 = layers.BatchNormalization()(l_1)
# hidden layer 2
l_2 = layers.Dense(128, activation='relu', name='layer_2')(l_1)
l_2 = layers.BatchNormalization()(l_2)
# hidden layer 3
l_3 = layers.Dense(128, activation='relu', name='layer_3')(l_2)

# Outputs
outputs = layers.Dense(num_classes, activation='softmax',
                       name='output_layer')(l_3)




model_batch_norm = keras.Model(inputs=inputs, outputs=outputs, name='dont_overfit_model_batch_norm')

# %%
model_batch_norm.summary()
# Out:
# Model: "dont_overfit_model_batch_norm"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 28, 28)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_9 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_1 (Dense)                 │ (None, 256)            │       200,960 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_2 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_3 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_layer (Dense)            │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 253,194 (989.04 KB)
#  Trainable params: 252,426 (986.04 KB)
#  Non-trainable params: 768 (3.00 KB)

# %%
model_batch_norm.compile(
    optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history_batch_norm = model_batch_norm.fit(
    x,
    y,
    batch_size=64,
    epochs=100,
    validation_split=0.2,
    shuffle=True
)
# Out:
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.5375 - loss: 1.4436 - val_accuracy: 0.6917 - val_loss: 1.7493
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9365 - loss: 0.3539 - val_accuracy: 0.8167 - val_loss: 1.4443
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9823 - loss: 0.1415 - val_accuracy: 0.8708 - val_loss: 1.2586
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9990 - loss: 0.0632 - val_accuracy: 0.8833 - val_loss: 1.1011
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0333 - val_accuracy: 0.8917 - val_loss: 0.9673
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0209 - val_accuracy: 0.8875 - val_loss: 0.8550
# Epoch 7/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.
evaluate(x_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
# Out:
# Test Loss: 0.37988054752349854
# Test Accuracy: 0.9041000008583069

# %% [markdown]
# ## Layer Normalization
#
# [Layer normalization](https://www.tensorflow.org/api_docs/python/tf/keras/layers/LayerNormalization) is another type of normalization technique. Unlike batch normalization, it normalizes the data across the features and is not dependent on the batch size, making it effective for both training and inference time normalization.
#
# Layer normalization computes the mean and variance used for normalization from all of the summed inputs. It is applied elementwise, i.e., independently to each input in a layer on a single training example.
#
# - With Functional API:
# ```python
# next_layer = layers.LayerNormalization(axis=1)(prev_layer)
# ```
#
# - With Sequential:
# ```python
# model.add(layers.LayerNormalization(axis=1))
# ```

# %%
# Input
inputs = tf.keras.Input(shape=(28, 28), name='input_layer')

# Convert the 2D image to a vector
flat = layers.Flatten()(inputs)

# Hidden layer 1
l_1 = layers.Dense(256, activation='relu', name='layer_1')(flat)
l_1 = layers.LayerNormalization(axis=1)(l_1)

# Hidden layer 2
l_2 = layers.Dense(128, activation='relu', name='layer_2')(l_1)
l_2 = layers.LayerNormalization(axis=1)(l_2)

# Hidden layer 3
l_3 = layers.Dense(128, activation='relu', name='layer_3')(l_2)

# Outputs
outputs = layers.Dense(num_classes, activation='softmax', name='output_layer')(l_3)

# Creating Model
model_layer_norm = keras.Model(inputs=inputs, outputs=outputs, name='dont_overfit_model_layer_norm')

# %%
model_layer_norm.compile(
    optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history_layer_norm = model_layer_norm.fit(
    x,
    y,
    batch_size=64,
    epochs=100,
    validation_split=0.2,
    shuffle=True
)
# Out:
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.5635 - loss: 1.4358 - val_accuracy: 0.8375 - val_loss: 0.6377
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8833 - loss: 0.4367 - val_accuracy: 0.8833 - val_loss: 0.4110
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9479 - loss: 0.2159 - val_accuracy: 0.8958 - val_loss: 0.3277
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9729 - loss: 0.1211 - val_accuracy: 0.8958 - val_loss: 0.3513
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9885 - loss: 0.0675 - val_accuracy: 0.9083 - val_loss: 0.2892
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9927 - loss: 0.0479 - val_accuracy: 0.9167 - val_loss: 0.2931
# Epoch 7/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9979 - loss: 0.0263 - val_accuracy: 0.9125 - val_loss: 0.3170
# Epoch 8/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0145 - val_accuracy: 0.9125 - val_loss: 0.3191
# Epoch 9/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0076 - val_accuracy: 0.9167 - val_loss: 0.3111
# Epoch 10/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 0.9167 - val_loss: 0.3166
# Epoch 11/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.9167 - val_loss: 0.3204
# Epoch 12/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.9167 - val_loss: 0.3225
# Epoch 13/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.9167 - val_loss: 0.3256
# Epoch 14/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.9167 - val_loss: 0.3285
# Epoch 15/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.9167 - val_loss: 0.3310
# Epoch 16/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.9167 - val_loss: 0.3336
# Epoch 17/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9208 - val_loss: 0.3357
# Epoch 18/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.9208 - val_loss: 0.3379
# Epoch 19/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.9208 - val_loss: 0.3401
# Epoch 20/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.9208 - val_loss: 0.3421
# Epoch 21/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9167 - val_loss: 0.3441
# Epoch 22/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9167 - val_loss: 0.3460
# Epoch 23/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9125 - val_loss: 0.3476
# Epoch 24/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9167 - val_loss: 0.3494
# Epoch 25/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.9167 - val_loss: 0.3511
# Epoch 26/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 9.4671e-04 - val_accuracy: 0.9167 - val_loss: 0.3526
# Epoch 27/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 8.8558e-04 - val_accuracy: 0.9167 - val_loss: 0.3537
# Epoch 28/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 8.2994e-04 - val_accuracy: 0.9167 - val_loss: 0.3562
# Epoch 29/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 7.7944e-04 - val_accuracy: 0.9167 - val_loss: 0.3579
# Epoch 30/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss:
# Epoch 72/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 1.4431e-04 - val_accuracy: 0.9208 - val_loss: 0.4025
# Epoch 73/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 1.4050e-04 - val_accuracy: 0.9208 - val_loss: 0.4032
# Epoch 74/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 1.3683e-04 - val_accuracy: 0.9208 - val_loss: 0.4040
# Epoch 75/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 1.3329e-04 - val_accuracy: 0.9208 - val_loss: 0.4047
# Epoch 76/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 1.2991e-04 - val_accuracy: 0.9208 - val_loss: 0.4054
# Epoch 77/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 1.2661e-04 - val_accuracy: 0.9208 - val_loss: 0.4061
# Epoch 78/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 1.2345e-04 - val_accuracy: 0.9208 - val_loss: 0.4066
# Epoch 79/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 1.2042e-04 - val_accuracy: 0.9208 - val_loss: 0.4073
# Epoch 80/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 1.1746e-04 - val_accuracy: 0.9208 - val_loss: 0.4080
# Epoch 81/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 1.1462e-04 - val_accuracy: 0.9208 - val_loss: 0.4087
# Epoch 82/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 1.1186e-04 - val_accuracy: 0.9208 - val_loss: 0.4093
# Epoch 83/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 1.0920e-04 - val_accuracy: 0.9208 - val_loss: 0.4099
# Epoch 84/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 1.0658e-04 - val_accuracy: 0.9208 - val_loss: 0.4104
# Epoch 85/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 1.0404e-04 - val_accuracy: 0.9208 - val_loss: 0.4109
# Epoch 86/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 1.0161e-04 - val_accuracy: 0.9167 - val_loss: 0.4113
# Epoch 87/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 9.9254e-05 - val_accuracy: 0.9167 - val_loss: 0.4117
# Epoch 88/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 9.6984e-05 - val_accuracy: 0.9167 - val_loss: 0.4123
# Epoch 89/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 9.4781e-05 - val_accuracy: 0.9167 - val_loss: 0.4127
# Epoch 90/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 9.2653e-05 - val_accuracy: 0.9167 - val_loss: 0.4133
# Epoch 91/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 9.0601e-05 - val_accuracy: 0.9167 - val_loss: 0.4138
# Epoch 92/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 8.8614e-05 - val_accuracy: 0.9167 - val_loss: 0.4144
# Epoch 93/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 8.6684e-05 - val_accuracy: 0.9167 - val_loss: 0.4149
# Epoch 94/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 8.4815e-05 - val_accuracy: 0.9167 - val_loss: 0.4155
# Epoch 95/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 8.3013e-05 - val_accuracy: 0.9167 - val_loss: 0.4161
# Epoch 96/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 8.1250e-05 - val_accuracy: 0.9167 - val_loss: 0.4165
# Epoch 97/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 7.9558e-05 - val_accuracy: 0.9167 - val_loss: 0.4171
# Epoch 98/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 7.7906e-05 - val_accuracy: 0.9167 - val_loss: 0.4176
# Epoch 99/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 7.6298e-05 - val_accuracy: 0.9167 - val_loss: 0.4181
# Epoch 100/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 7.4756e-05 - val_accuracy: 0.9167 - val_loss: 0.4187

# %%
plot_history(history_layer_norm)

# %%
results = model_layer_norm.evaluate(x_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
# Out:
# Test Loss: 0.4260854125022888
# Test Accuracy: 0.9125000238418579

# %% [markdown]
# <a id='l1_l2_elasticnet'></a>
# ## L1, L2 and ElasticNet
#
# During training, the network learns the weights and biases configuration that minimizes a given loss function. Regularization adds a penalty term to the loss to prevent weights from becoming too large.
#
# * [L1 regularization](https://developers.google.com/machine-learning/glossary/#L1_regularization), where the cost added is proportional to the absolute value of the weights coefficients ("L1 norm" of the weights).
#
# ```python
# tf.keras.regularizers.l1(l1=0.01)
#
# layers.Dense(3, kernel_regularizer='l1')
#
# ```
#
#
# * [L2 regularization](https://developers.google.com/machine-learning/glossary/#L2_regularization), where the cost added is proportional to the square of the value of the weights coefficients ( "L2 norm" of the weights).
#
# ```python
# tf.keras.regularizers.l2(l2=0.01)
#
# layers.Dense(3, kernel_regularizer='l2')
#
# ```
# * L1_L2 or Elastic Net.
#
# ```python
# tf.keras.regularizers.l1_l2(
#     l1=0.01, l2=0.01
# )
#
# layers.Dense(3, kernel_regularizer='l1_l2')
#
# ```
#
# Furthermore, it is possible to choose whether to include the penalty in the cost function on the weights, the biases or on the activation, with the following arguments:
# - `kernel_regularizer`: only on weights.
# - `bias_regularizer`: only on biases.
# - `activity_regularizer`: on full output.
#
# [link to documentation](https://keras.io/api/layers/regularizers/).

# %%
from tensorflow.keras import regularizers

# %%
kernel_regularizer_l1 = regularizers.l1_l2(l1=1e-5, l2=5e-4)
kernel_regularizer_l2 = regularizers.l2(5e-4)
kernel_regularizer_l3 = regularizers.l1(1e-5)

# %%
# Input
inputs = tf.keras.Input(shape=(28, 28), name='input_layer')
# Convert the 2D image to a vector
flat = layers.Flatten()(inputs)

# hidden layer 1
l_1 = layers.Dense(256, activation='relu',
                   kernel_regularizer=kernel_regularizer_l1, name='layer_1')(flat)
# hidden layer 2
l_2 = layers.Dense(128, activation='relu',
                   kernel_regularizer=kernel_regularizer_l2, name='layer_2')(l_1)
# hidden layer 3
l_3 = layers.Dense(128, activation='relu',
                   kernel_regularizer=kernel_regularizer_l3, name='layer_3')(l_2)

# Outputs
outputs = layers.Dense(num_classes, activation='softmax',
                       name='output_layer')(l_3)


model_regularizers = keras.Model(inputs=inputs,
                                 outputs=outputs,
                                 name='dont_overfit_model_regularizers')

# %%
model_regularizers.summary()
# Out:
# Model: "dont_overfit_model_regularizers"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 28, 28)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_12 (Flatten)            │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_1 (Dense)                 │ (None, 256)            │       200,960 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_2 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_3 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_layer (Dense)            │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 251,658 (983.04 KB)
#  Trainable params: 251,658 (983.04 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_regularizers.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history_regularizers = model_regularizers.fit(
    x,
    y,
    batch_size=64,
    epochs=100,
    validation_split=0.2,
    shuffle=True
)
# Out:
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.4990 - loss: 2.1158 - val_accuracy: 0.7958 - val_loss: 1.3191
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8052 - loss: 0.9868 - val_accuracy: 0.8667 - val_loss: 0.8053
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9042 - loss: 0.6168 - val_accuracy: 0.8625 - val_loss: 0.7256
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9365 - loss: 0.4761 - val_accuracy: 0.8708 - val_loss: 0.7355
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9625 - loss: 0.4155 - val_accuracy: 0.8667 - val_loss: 0.6664
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9667 - loss: 0.3869 - val_accuracy: 0.8750 - val_loss: 0.6654
# Epoch 7/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9667 - loss: 0.3543 - val_accuracy: 0.8750 - val_loss: 0.6726
# Epoch 8/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9771 - loss: 0.3265 - val_accuracy: 0.8625 - val_loss: 0.7115
# Epoch 9/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9656 - loss: 0.3474 - val_accuracy: 0.9042 - val_loss: 0.6032
# Epoch 10/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9750 - loss: 0.3269 - val_accuracy: 0.9083 - val_loss: 0.6388
# Epoch 11/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9792 - loss: 0.3145 - val_accuracy: 0.8750 - val_loss: 0.8344
# Epoch 12/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9833 - loss: 0.2897 - val_accuracy: 0.8958 - val_loss: 0.6477
# Epoch 13/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9937 - loss: 0.2576 - val_accuracy: 0.8917 - val_loss: 0.6641
# Epoch 14/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.2397 - val_accuracy: 0.8958 - val_loss: 0.6311
# Epoch 15/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.2276 - val_accuracy: 0.8958 - val_loss: 0.6439
# Epoch 16/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.2211 - val_accuracy: 0.8958 - val_loss: 0.6431
# Epoch 17/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0
# Epoch 66/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0836 - val_accuracy: 0.8875 - val_loss: 0.5137
# Epoch 67/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0821 - val_accuracy: 0.8875 - val_loss: 0.5108
# Epoch 68/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0806 - val_accuracy: 0.8875 - val_loss: 0.5089
# Epoch 69/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0791 - val_accuracy: 0.8875 - val_loss: 0.5060
# Epoch 70/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0777 - val_accuracy: 0.8875 - val_loss: 0.5047
# Epoch 71/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0763 - val_accuracy: 0.8917 - val_loss: 0.5023
# Epoch 72/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0750 - val_accuracy: 0.8917 - val_loss: 0.5005
# Epoch 73/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0737 - val_accuracy: 0.8875 - val_loss: 0.4987
# Epoch 74/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0724 - val_accuracy: 0.8875 - val_loss: 0.4970
# Epoch 75/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0712 - val_accuracy: 0.8875 - val_loss: 0.4966
# Epoch 76/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0699 - val_accuracy: 0.8875 - val_loss: 0.4951
# Epoch 77/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0687 - val_accuracy: 0.8833 - val_loss: 0.4940
# Epoch 78/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0675 - val_accuracy: 0.8792 - val_loss: 0.4919
# Epoch 79/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0664 - val_accuracy: 0.8792 - val_loss: 0.4887
# Epoch 80/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0653 - val_accuracy: 0.8792 - val_loss: 0.4867
# Epoch 81/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0642 - val_accuracy: 0.8792 - val_loss: 0.4861
# Epoch 82/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0632 - val_accuracy: 0.8833 - val_loss: 0.4864
# Epoch 83/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0621 - val_accuracy: 0.8833 - val_loss: 0.4863
# Epoch 84/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0611 - val_accuracy: 0.8833 - val_loss: 0.4840
# Epoch 85/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0601 - val_accuracy: 0.8875 - val_loss: 0.4825
# Epoch 86/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0592 - val_accuracy: 0.8833 - val_loss: 0.4815
# Epoch 87/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0582 - val_accuracy: 0.8833 - val_loss: 0.4797
# Epoch 88/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0573 - val_accuracy: 0.8833 - val_loss: 0.4781
# Epoch 89/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0564 - val_accuracy: 0.8833 - val_loss: 0.4769
# Epoch 90/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0555 - val_accuracy: 0.8833 - val_loss: 0.4749
# Epoch 91/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0547 - val_accuracy: 0.8792 - val_loss: 0.4732
# Epoch 92/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0539 - val_accuracy: 0.8833 - val_loss: 0.4670
# Epoch 93/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0530 - val_accuracy: 0.8833 - val_loss: 0.4635
# Epoch 94/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0523 - val_accuracy: 0.8875 - val_loss: 0.4591
# Epoch 95/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0515 - val_accuracy: 0.8792 - val_loss: 0.4612
# Epoch 96/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0509 - val_accuracy: 0.8750 - val_loss: 0.4653
# Epoch 97/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0503 - val_accuracy: 0.8708 - val_loss: 0.4650
# Epoch 98/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0499 - val_accuracy: 0.8792 - val_loss: 0.4803
# Epoch 99/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0496 - val_accuracy: 0.8667 - val_loss: 0.5000
# Epoch 100/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0502 - val_accuracy: 0.8833 - val_loss: 0.5116

# %% [markdown]
# Lets compare the weights norms of the model without regularization and with regularization.

# %%
for ly in model.layers:
    if 'layer_' in ly.name:
        W, b = ly.get_weights()
        l2_norm = np.sum(W**2)**0.5
        zero_elems = len(W[np.abs(W) < 1e-14])
        sparsity = zero_elems / np.prod(W.shape)
        sparsity = np.round(100 * sparsity, 2)
        print('L2 norm {0} weights: {1}, shape:{2}, sparsity:{3}'.format(
            ly.name, l2_norm, W.shape,sparsity))
# Out:
# L2 norm layer_1 weights: 39.2457275390625, shape:(784, 256), sparsity:0.0
# L2 norm layer_2 weights: 20.811128616333008, shape:(256, 128), sparsity:0.0
# L2 norm layer_3 weights: 16.01960563659668, shape:(128, 128), sparsity:0.0

# %%
for ly in model_regularizers.layers:
    if 'layer_' in ly.name:
        W, b = ly.get_weights()
        l2_norm = np.sum(W**2)**0.5
        zero_elems = len(W[np.abs(W) < 1e-14])
        sparsity = zero_elems / np.prod(W.shape)
        sparsity = np.round(100 * sparsity, 2)
        print('L2 norm {0} weights: {1}, shape:{2}, sparsity:{3}'.format(
            ly.name, l2_norm, W.shape,sparsity))
# Out:
# L2 norm layer_1 weights: 4.2852463722229, shape:(784, 256), sparsity:0.0
# L2 norm layer_2 weights: 5.981822490692139, shape:(256, 128), sparsity:7.43
# L2 norm layer_3 weights: 12.404071807861328, shape:(128, 128), sparsity:0.0

# %%
for ly in model_batch_norm.layers:
    if 'layer_' in ly.name:
        W, b = ly.get_weights()
        l2_norm = np.sum(W**2)**0.5
        zero_elems = len(W[np.abs(W) < 1e-14])
        sparsity = zero_elems / np.prod(W.shape)
        sparsity = np.round(100 * sparsity, 2)
        print('L2 norm {0} weights: {1}, shape:{2}, sparsity:{3}'.format(
            ly.name, l2_norm, W.shape,sparsity))
# Out:
# L2 norm layer_1 weights: 19.966567993164062, shape:(784, 256), sparsity:0.0
# L2 norm layer_2 weights: 13.248637199401855, shape:(256, 128), sparsity:0.0
# L2 norm layer_3 weights: 12.180683135986328, shape:(128, 128), sparsity:0.0

# %%
plot_history(history_regularizers)

# %%
results = model_regularizers.evaluate(x_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
# Out:
# Test Loss: 0.5210163593292236
# Test Accuracy: 0.8942999839782715

# %% [markdown]
# ### Question 3:
# #### What happens if you change the regularizers?

# %%
kernel_regularizer_l1 = regularizers.l1_l2(l1=1e-5, l2=5e-4)
kernel_regularizer_l2 = regularizers.l2(l2=5e-4)
kernel_regularizer_l3 = regularizers.l1_l2(l1=1e-5, l2=5e-4)
# Input
inputs = tf.keras.Input(shape=(28, 28), name='input_layer')
# Convert the 2D image to a vector
flat = layers.Flatten()(inputs)

# hidden layer 1
l_1 = layers.Dense(256, activation='relu',
                   kernel_regularizer=kernel_regularizer_l1, name='layer_1')(flat)
# hidden layer 2
l_2 = layers.Dense(128, activation='relu',
                   kernel_regularizer=kernel_regularizer_l2, name='layer_2')(l_1)
# hidden layer 3
l_3 = layers.Dense(128, activation='relu',
                   kernel_regularizer=kernel_regularizer_l3, name='layer_3')(l_2)

# Outputs
outputs = layers.Dense(num_classes, activation='softmax',
                       name='output_layer')(l_3)


model_regularizers = keras.Model(inputs=inputs,
                                 outputs=outputs,
                                 name='dont_overfit_model_regularizers')
model_regularizers.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history_regularizers = model_regularizers.fit(
    x,
    y,
    batch_size=64,
    epochs=100,
    validation_split=0.2,
    shuffle=True
)
plot_history(history_regularizers)
# Out:
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.4656 - loss: 2.2155 - val_accuracy: 0.7917 - val_loss: 1.4562
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8188 - loss: 1.0846 - val_accuracy: 0.8417 - val_loss: 0.9090
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8969 - loss: 0.6980 - val_accuracy: 0.8458 - val_loss: 0.8120
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9469 - loss: 0.5551 - val_accuracy: 0.8708 - val_loss: 0.7486
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9667 - loss: 0.4887 - val_accuracy: 0.8917 - val_loss: 0.6544
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9750 - loss: 0.4489 - val_accuracy: 0.8750 - val_loss: 0.6733
# Epoch 7/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9729 - loss: 0.4189 - val_accuracy: 0.8708 - val_loss: 0.7817
# Epoch 8/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.
evaluate(x_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
# Out:
# Test Loss: 0.520316481590271
# Test Accuracy: 0.9082000255584717

# %% [markdown]
# ## Combine L2 Regularization, Dropout, LN BN
#
# Use L2:
# ```python
# kernel_regularizer_l2 = regularizers.l2(5e-4)
# ```
# And Dropout:
#
# ```python
# next_layer = layers.Dropout(0.4)(prev_layer)
# ```

# %%
kernel_regularizer_l2 = ...

# %%
inputs = tf.keras.Input(shape=(28, 28), name='input_layer')

# Convert the 2D image to a vector
flat = layers.Flatten()(inputs)


# Add L2-normalization
l_1 = layers.Dense(128, activation='relu',
                   kernel_regularizer=regularizers.l2(l2=5e-4),
                   name='layer_1')(flat)
l_1 = layers.LayerNormalization(axis=1)(l_1)

# Add dropout
l_1 = layers.Dropout(0.5)(l_1)


# Add L2-normalization
l_2 = layers.Dense(64,
                   activation='relu',
                   kernel_regularizer=regularizers.l2(l2=5e-4),
                   name='layer_2')(l_1)
l_2 = layers.LayerNormalization(axis=1)(l_1)

# Add dropout
l_2 = layers.Dropout(0.5)(l_2)


# Add L2-normalization
l_3 = layers.Dense(32,
                   activation='relu',
                   kernel_regularizer=regularizers.l2(l2=5e-4),
                   name='layer_3')(l_2)
l_3 = layers.LayerNormalization(axis=1)(l_1)

# Add dropout
l_3 = layers.Dropout(0.5)(l_3)


outputs = layers.Dense(10, activation='softmax',
                       name='output_layer')(l_3)

model_combination = keras.Model(inputs=inputs,
                                 outputs=outputs,
                                 name='dont_overfit_model_regularizers')

# %%
model_combination.compile(
    optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy']
)

# %%
history_combination = model_combination.fit(
    x,
    y,
    batch_size=64,
    epochs=100,
    validation_split=0.2,
    shuffle=True
)
# Out:
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.1948 - loss: 2.8649 - val_accuracy: 0.6792 - val_loss: 1.1935
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4333 - loss: 1.7859 - val_accuracy: 0.7917 - val_loss: 0.7673
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6021 - loss: 1.2461 - val_accuracy: 0.8292 - val_loss: 0.6194
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6729 - loss: 1.0175 - val_accuracy: 0.8292 - val_loss: 0.5848
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7375 - loss: 0.8759 - val_accuracy: 0.8375 - val_loss: 0.5641
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7458 - loss: 0.8078 - val_accuracy: 0.8417 - val_loss: 0.4932
# Epoch 7/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7958 - loss: 0.6983 - val_accuracy: 0.8625 - val_loss: 0.4899
# Epoch 8/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8083 - loss: 0.6711 - val_accuracy: 0.8833 - val_loss: 0.4559
# Epoch 9/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8417 - loss: 0.5797 - val_accuracy: 0.8708 - val_loss: 0.4851
# Epoch 10/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8573 - loss: 0.5361 - val_accuracy: 0.8833 - val_loss: 0.4681
# Epoch 11/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8417 - loss: 0.5500 - val_accuracy: 0.8792 - val_loss: 0.4392
# Epoch 12/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8792 - loss: 0.4504 - val_accuracy: 0.8833 - val_loss: 0.4483
# Epoch 13/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8740 - loss: 0.4785 - val_accuracy: 0.8875 - val_loss: 0.4416
# Epoch 14/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8896 - loss: 0.4486 - val_accuracy: 0.8833 - val_loss: 0.4666
# Epoch 15/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8896 - loss: 0.4430 - val_accuracy: 0.8875 - val_loss: 0.4541
# Epoch 16/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8823 - loss: 0.4454 - val_accuracy: 0.8958 - val_loss: 0.4634
# Epoch 17/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9156 - loss: 0.3794 - val_accuracy: 0.8917 - val_loss: 0.4627
# Epoch 18/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9167 - loss: 0.3622 - val_accuracy: 0.8875 - val_loss: 0.4705
# Epoch 19/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.
# Epoch 94/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9833 - loss: 0.1216 - val_accuracy: 0.8792 - val_loss: 0.5955
# Epoch 95/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9792 - loss: 0.1363 - val_accuracy: 0.9042 - val_loss: 0.5903
# Epoch 96/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9833 - loss: 0.1250 - val_accuracy: 0.8792 - val_loss: 0.6181
# Epoch 97/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9823 - loss: 0.1219 - val_accuracy: 0.8917 - val_loss: 0.6198
# Epoch 98/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9823 - loss: 0.1286 - val_accuracy: 0.8792 - val_loss: 0.6611
# Epoch 99/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9802 - loss: 0.1274 - val_accuracy: 0.8875 - val_loss: 0.6224
# Epoch 100/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9740 - loss: 0.1419 - val_accuracy: 0.8917 - val_loss: 0.6787

# %%
plot_history(history_combination)

# %%
results = model_combination.evaluate(x_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
# Out:
# Test Loss: 0.6477820873260498
# Test Accuracy: 0.8949000239372253

# %% [markdown]
# ## Noise injection
#
# Apply additive zero-mean Gaussian noise.
#
# With Functional API:
# ```python
# next_layer = layers.GaussianNoise(stddev)(prev_layer)
# ```
# With Sequential:
# ```python
# model.add(layers.GaussianNoise(stddev)())
# ```

# %%
stddev = 2

# Input
inputs = tf.keras.Input(shape=(28,28), name='input_layer')
# Convert the 2D image to a vector
flat = layers.Flatten()(inputs)

# hidden layer 1
l_1 = layers.Dense(256, activation='relu', name='layer_1')(flat)
l_1 = layers.GaussianNoise(stddev, name='noise_l1')(l_1)
# hidden layer 2
l_2 = layers.Dense(128, activation='relu', name='layer_2')(l_1)
l_2 = layers.GaussianNoise(stddev, name='noise_l2')(l_2)
# hidden layer 3
l_3 = layers.Dense(128, activation='relu', name='layer_3')(l_2)
l_3 = layers.GaussianNoise(stddev, name='noise_l3')(l_3)

# Outputs
outputs = layers.Dense(num_classes, activation='softmax', name='output_layer')(l_3)

model_noise = keras.Model(inputs=inputs, outputs=outputs, name='dont_overfit_model_noise')

# %%
model_noise.summary()

# %%
model_noise.compile(
    optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history_noise = model_noise.fit(
    x,
    y,
    batch_size=64,
    epochs=100,
    validation_split=0.2,
    shuffle=True
)

# %%
plot_history(history_noise)

# %%
results = model_noise.evaluate(x_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))

# %% [markdown]
# <a id='early_stopping'></a>
# ## Early Stopping
#
# Another of the most used techniques in neural network training is **early stopping**. It basically consists of stopping the training process in an Epoch prior to the one defined in the compilation.
#
# This, in addition to resulting in a model with less overfitting, saves unnecessary computation time.
#
# To do this, we can use the [Keras callbacks](https://keras.io/api/callbacks/), objects that perform actions at different times during training. Specifically, we will make use of [`EarlyStopping`](https://keras.io/api/callbacks/early_stopping/).
#
# ```python
# tf.keras.callbacks.EarlyStopping(
#     monitor="val_loss",
#     min_delta=0,
#     patience=0,
#     restore_best_weights=True,
#     verbose=0,
# )
# ```
#
# - **monitor**: Quantity to be monitored. Depending on the evolution, it will be decided to stop training.
#
# - **min_delta**: Minimum change in the monitored quantity to qualify as an improvement, i.e. an absolute change of less than min_delta, will count as no improvement.
#
# - **patience**: Number of epochs with no improvement after which training will be stopped.
#
# - **verbose**: verbosity mode.
#
# There are other callbacks that can be very useful such as:
# - [`ModelCheckpoint`](https://keras.io/api/callbacks/model_checkpoint/), which allows storing the state of a model at different times of training. This is very useful in trainings that can take hours or days.
# - [`TensorBoard`](https://keras.io/api/callbacks/tensorboard/), which allows the use of [TensorBoard](https://www.tensorflow.org/tensorboard?hl=es-419), framework TensorFlow for visualizing metrics and evaluating models.

# %%
es_callback = keras.callbacks.EarlyStopping(
    monitor='val_loss',  # can be 'val_accuracy'
    patience=5,  # if during 5 epochs there is no improvement in `val_loss`, the execution will stop
    restore_best_weights=True,
    verbose=1)

# %% [markdown]
# Lets create the same model:

# %%
# Input
inputs = tf.keras.Input(shape=(28,28), name='input_layer')
# Convert the 2D image to a vector
flat = layers.Flatten()(inputs)

# hidden layer 1
l_1 = layers.Dense(256, activation='relu', name='layer_1')(flat)
# hidden layer 2
l_2 = layers.Dense(128, activation='relu', name='layer_2')(l_1)
# hidden layer 3
l_3 = layers.Dense(128, activation='relu', name='layer_3')(l_2)

# Outputs
outputs = layers.Dense(num_classes, activation='softmax', name='output_layer')(l_3)

model_early_stopping = keras.Model(inputs=inputs, outputs=outputs, name='dont_overfit_model_early_stopping')

# %%
model_early_stopping.summary()

# %%
model_early_stopping.compile(optimizer='adam',
                             loss='sparse_categorical_crossentropy',
                             metrics=['accuracy'])

# %%
history_early_stopping = model_early_stopping.fit(
    x,
    y,
    batch_size=64,
    epochs=100,
    validation_split=0.2,
    shuffle=True,
    callbacks=[es_callback]
)

# %%
plot_history(history_early_stopping)

# %%
results = model_early_stopping.evaluate(x_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))

# %% [markdown]
# <a id='tensorboard'></a>
# # TensorBoard
#
#
#
# [TensorBoard](https://www.tensorflow.org/tensorboard) is a set of TensorFlow tools that allows us to represent the evolution and results of the training.
#
# In order to introduce this tool, the following is a notebook from the [TensorFlow tutorial on TensorBoard](https://www.tensorflow.org/tensorboard/get_started).

# %% [markdown]
# Load TensorBoard notebook extension.

# %%
# %load_ext tensorboard

# %%
import tensorflow as tf
import datetime

# %% [markdown]
# We build the model. The input layer will have a dimension of `28x28`. The output layer, in a multiclass classification problem with 10 possible classes, will be made up of 10 neurons with [softmax activation function](https://keras.io/api/layers/activations/#softmax-function ).

# %%
kernel_regularizer_l2 = keras.regularizers.l2(5e-4)

model = tf.keras.models.Sequential(name="tensorboard_model")
model.add(layers.Flatten(input_shape=(28, 28)))

# Hidden Layer + regularization
model.add(layers.Dense(64, activation='relu', name='layer_1'))
model.add(layers.Dense(64, activation='relu',
                       kernel_regularizer=kernel_regularizer_l2, name='layer_2'))
# output layer
model.add(layers.Dense(10, activation='softmax', name='output_layer'))

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# In the [example with early stopping](#early_stopping) the Keras callbacks were presented. To use TensorBoard we will need to include the [`TensorBoard` callback](https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/TensorBoard) to the training.
#
# This callback will create and store the logs in the directory that we indicate.
#
# By default it will create a directory called "logs" in the directory where this notebook is running.

# %%
log_dir = 'logs/fit/' + datetime.datetime.now().strftime('%Y%m%d-%H%M%S')

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# %%
es_callback = keras.callbacks.EarlyStopping(
    monitor='val_loss',  # can be 'val_accuracy'
    patience=10,  # if during 10 epochs there is no improvement in `val_loss`, the execution will stop
    restore_best_weights=True,
    verbose=1)

# %% [markdown]
# Train the model

# %%
model.fit(
    x=x_train,
    y=y_train,
    epochs=20,
    validation_split=0.2,
    batch_size=32,
    callbacks=[tensorboard_callback, es_callback]
)

# %%
results = model.evaluate(x_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))

# %% [markdown]
# To ** start TensorBoard ** we can execute the following cell or, from the command line, execute:
#
#     tensorboard --logdir logs/fit
#
# An application will be launched that will be listening by default on port 6006. It is possible to use TensorBoard by opening [localhost: 6006 /](http://localhost:6006/) in a browser.

# %%
# %tensorboard --logdir logs/fit

# %% [markdown]
# A brief overview of the dashboards shown (tabs in top navigation bar):
#
# * The **Scalars** dashboard shows how the loss and metrics change with every epoch. You can use it to also track training speed, learning rate, and other scalar values.
# * The **Graphs** dashboard helps you visualize your model. In this case, the Keras graph of layers is shown which can help you ensure it is built correctly.
# * The **Distributions** and **Histograms** dashboards show the distribution of a Tensor over time. This can be useful to visualize weights and biases and verify that they are changing in an expected way.

# %% [markdown]
# ### Improve the last model with some regularization techniques to obtain at least `0.98` of test accuracy

# %%
model = tf.keras.models.Sequential()
model.add(layers.Flatten(input_shape=(28, 28)))

## Hidden Layer + regularization
model.add(...)
### output layer
model.add(layers.Dense(10, activation='softmax'))

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model.fit(
    x=x_train,
    y=y_train,
    epochs=5,
    validation_split=0.2,
    batch_size=64
)
results = model.evaluate(x_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))

# %%
model.fit(
    x=x_train,
    y=y_train,
    epochs=...,
    validation_split=0.2,
    batch_size=...,
    callbacks=...
)
results = model.evaluate(x_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))

# %% [markdown]
# ### Plotting Predictions

# %%
predictions = model.predict(x_test)
predicted_classes = np.argmax(predictions, -1)

# %%
L = 5
W = 5
fig, axes = plt.subplots(L, W, figsize=(14, 14))
axes = axes.ravel()

for i in np.arange(0, L * W):
    ind = np.random.randint(len(y_test))
    axes[i].imshow(x_test[ind].reshape(28, 28))
    prob_pred = np.max(predictions[ind, :])
    class_pred = int(predicted_classes[ind])
    original_class = int(y_test[ind])
    if class_pred == original_class:
        color = 'green'
    else:
        color = 'red'
    title = "Pred: {0} \n Target: {1} \n Prob: {2:.3f}".format(
    class_pred, original_class, prob_pred)
    axes[i].set_title(title, color=color)
    axes[i].axis('off')

plt.subplots_adjust(wspace=0.5)

# %% [markdown]
# ## Summary: Regularization Techniques Comparison
#
# | Technique | Description | Key Parameter |
# |-----------|-------------|---------------|
# | **Simpler Model** | Reduce number of layers/neurons | Architecture design |
# | **Smaller Batch Size** | Add noise to gradient estimation | `batch_size` |
# | **Dropout** | Randomly drop neurons during training | `rate` (0.0-1.0) |
# | **Batch Normalization** | Normalize activations per batch | - |
# | **Layer Normalization** | Normalize activations per sample | `axis` |
# | **L1 Regularization** | Penalty on absolute weight values (sparsity) | `l1` coefficient |
# | **L2 Regularization** | Penalty on squared weight values | `l2` coefficient |
# | **Gaussian Noise** | Add noise to layer outputs | `stddev` |
# | **Early Stopping** | Stop training when validation loss stops improving | `patience` |
#
# **Tips:**
# - Start with a simple model and add complexity if needed
# - Dropout (0.2-0.5) and L2 regularization are commonly used together
# - Early stopping is almost always recommended
# - Monitor validation loss to detect overfitting early
